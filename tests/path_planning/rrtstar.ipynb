# %%
import sys
sys.path.append('../../')
import numpy as np
from IPython.display import HTML

from rover_simulator.world import World
from rover_simulator.rover import BasicRover
from rover_simulator.history import SimpleHistory
from rover_simulator.navigation.path_planner.sampling_base import RRTstar

# %%
world = World()
world.read_objects("../../rover_simulator/examples/environment_simple.txt")

rover_r = 0.5
start_pose = np.array([1.0, 1.0, 0.0])
goal_pos = np.array([13.0, 15.0])

path_planner = RRTstar(
    start_pose,
    goal_pos,
    enlarge_range=rover_r,
    explore_region=[[0, 20], [0, 20]],
    known_obstacles=world.obstacles
)

rover = BasicRover(
    start_pose, rover_r,
    sensor=None,
    mapper=None,
    path_planner=path_planner,
    localizer=None,
    controller=None,
    history=SimpleHistory()
)

world.append_rover(rover)

# %%
rover.waypoints = rover.path_planner.calculate_path(
    max_iter=500,
    log_history=True
)

# %%
path_planner.draw(
    xlim=[0.0, 20.0],
    ylim=[0.0, 20.0],
    obstacles=world.obstacles, enlarge_range=rover.r
)

# %%
world.draw(
    xlim=[0, 20], ylim=[0, 20],
    start_pos=start_pose[0:2], goal_pos=goal_pos,
    enlarge_range=rover.r, draw_waypoints_flag=True
)

# %%
path_planner.animate(
    xlim=[0, 20], ylim=[0, 20],
    enlarge_range=0.5,
    end_step=500
)
HTML(path_planner.ani.to_jshtml())
# path_planner.ani.save("./rrtstar.mp4", dpi=300)
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
